# %% [markdown]
# Flavor – вкусовой букет, Баланс, – можно посмотреть по всем
#
# Можно сравнить, какой показатель помогает зерну стать спешелти чаще всего
#
# Нужен рандом - где-то выше 80, где-то ниже:
# можно выбрать выборку - 10 арома 5 баланс и тд - тот показатель, как самый высокий - больше всего играет на баллах
#
# Можно сделать вывод: что встречается чаще всего в арабике, а что в робусте (что ярче там или там)
# можно сравнить лидирующие позиции индексов, сделать график или несколько

# %%
import pandas as pd

# %%
df_rob = pd.read_csv('data_robusta.csv', sep = ';')

# %%
df_arab = pd.read_csv('data_arabica.csv', sep = ';')

# %%
df_rob.sort_values('Salt / Acid', ascending = False).head(5)
# Out:
#    quality_score  Species Country of Origin                       Farm Name  \
# 2          83.25  Robusta             India               Sethuraman Estate
# 1          83.50  Robusta             India  Sethuraman Estate Kaapi Royale
# 5          82.75  Robusta             India                             NaN
# 0          83.75  Robusta            Uganda   Kyangundu cooperative society
# 8          82.50  Robusta             India               Sethuraman Estate
#
#                       Mill Altitude                       Region  \
# 2                      NaN    1000m                  Chikmagalur
# 1        Sethuraman Estate     3170  Chikmagalur Karnataka Indua
# 5                   (self)   3,000'                  Chikmagalur
# 0  Ankole coffee producers     1488         Sheema South Western
# 8        Sethuraman Estate     1000        Chikmagalur Karnataka
#
#    Harvest Year                       Owner.1  Fragrance / Aroma  Flavor  \
# ...

# %%
df_rob.columns = df_rob.columns.str.lower().str.replace(' ', '_')

# %%
df_rob['altitude'].fillna('0', inplace = True)

# %%
df_rob['altitude'] = df_rob['altitude'].astype(int)

# %%
df_rob.sort_values('altitude', ascending = False)
# Out:
#     quality_score  species country_of_origin  \
# 1           83.50  Robusta             India
# 7           82.50  Robusta             India
# 18          80.58  Robusta            Uganda
# 17          80.92  Robusta            Uganda
# 0           83.75  Robusta            Uganda
# 14          81.50  Robusta            Uganda
# 13          81.50  Robusta            Uganda
# 4           83.00  Robusta            Uganda
# 3           83.00  Robusta            Uganda
# 19          80.50  Robusta            Uganda
# 9           82.42  Robusta            Uganda
# 10          81.75  Robusta            Uganda
# 8           82.50  Robusta             India
# 11          81.58  Robusta             India
# 15          81.42  Robusta             India
# 2           83.25  Robusta             India
# 22          79.33  Robusta     United States
# 5           82.75  Robusta             India
# 25          77.17  Robusta     United States
# 21          80.17  Robusta             India
# ...

# %%
df_rob
# Out:
#     quality_score  species country_of_origin  \
# 0           83.75  Robusta            Uganda
# 1           83.50  Robusta             India
# 2           83.25  Robusta             India
# 3           83.00  Robusta            Uganda
# 4           83.00  Robusta            Uganda
# 5           82.75  Robusta             India
# 6           82.58  Robusta             India
# 7           82.50  Robusta             India
# 8           82.50  Robusta             India
# 9           82.42  Robusta            Uganda
# 10          81.75  Robusta            Uganda
# 11          81.58  Robusta             India
# 12          81.58  Robusta             India
# 13          81.50  Robusta            Uganda
# 14          81.50  Robusta            Uganda
# 15          81.42  Robusta             India
# 16          81.25  Robusta             India
# 17          80.92  Robusta            Uganda
# 18          80.58  Robusta            Uganda
# 19          80.50  Robusta            Uganda
# ...

# %%
df_arab.sort_values('Acidity', ascending = False).head(5)
# Out:
#    quality_score  Species Country of Origin  Farm Name       Mill   Altitude  \
# 0          90.58  Arabica          Ethiopia  METAD PLC  METAD PLC  1950-2200
# 1          89.92  Arabica          Ethiopia  METAD PLC  METAD PLC  1950-2200
# 4          88.83  Arabica          Ethiopia  METAD PLC  METAD PLC  1950-2200
# 5          88.83  Arabica            Brazil        NaN        NaN        NaN
# 6          88.75  Arabica              Peru        NaN        HVC        NaN
#
#                      Region Harvest Year        Owner.1  Aroma  Flavor  \
# 0         GUJI-HAMBELA/GOYO         2014      metad plc   8.67    8.83
# 1        GUJI-HAMBELA/ALAKA         2014      metad plc   8.75    8.67
# 4  GUJI-HAMBELA/BISHAN FUGU         2014      metad plc   8.25    8.50
# 5                       NaN         2013      Ji-Ae Ahn   8.58    8.42
# 6                       NaN         2012  Hugo Valdivia   8.42    8.50
#
# ...
